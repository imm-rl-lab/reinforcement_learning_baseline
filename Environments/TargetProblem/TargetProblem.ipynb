# %%
import os, sys
sys.path.insert(0, os.path.abspath('../..'))
from Utilities.OneAgentReader import OneAgentReader as Reader

reader = Reader('TargetProblem')
reader.add_plots_for_all_params('TargetProblem_with_CCEM')
