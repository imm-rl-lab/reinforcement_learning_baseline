# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
import torch.nn as nn
from Environments.TargetProblem.TargetProblem import TargetProblem
from Environments.TargetProblem.TargetProblemVisualizer import TargetProblemVisualizer
from Agents.CVI import CVI, VModelWithGradient
from Agents.Utilities.SequentialNetwork import SequentialNetwork
from Agents.Utilities.Noises import OUNoise
from Solvers import OneAgentSolver as solver 
# %load_ext autoreload
# %autoreload 2

#learning parameters
episode_n = 201

#environment initialization
env = TargetProblem(dt=0.5, inner_step_n=5)

#agent initialization
network = SequentialNetwork([env.state_dim, 256, 128, 1], nn.ReLU())
v_model = VModelWithGradient(env.action_min, env.action_max, network, env.r, env.g)
noise = OUNoise(action_dim=env.action_dim, threshold_decrease=1.5/episode_n)
agent = CVI(env.action_min, env.action_max, v_model, noise, env.virtual_step_for_batch,
            batch_size=128, gamma=1, tau=1e-2, v_model_lr=1e-3, predicted_step_n=4)

#learning
visualizer = TargetProblemVisualizer(waiting_for_show=20)
solver.go(env, agent, episode_n=episode_n, show=visualizer.show, session_len=2500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-101f030a1af3> in <module>
#      26 #learning
#      27 visualizer = TargetProblemVisualizer(waiting_for_show=20)
# ---> 28 solver.go(env, agent, episode_n=episode_n, show=visualizer.show, session_len=2500)
#
# ~\Desktop\IMM-RL-Lab\finite-horizon_control_problems\Solvers\OneAgentSolver.py in go(env, agent, show, episode_n, session_n, session_len, agent_learning)
#      30
#      31     for episode in range(episode_n):
# ---> 32         sessions = [get_session(env, agent, session_len, agent_learning) for i in range(session_n)]
#      33
#      34         show(env, agent, episode, sessions)
#
# ~\Desktop\IMM-RL-Lab\finite-horizon_control_problems\Solvers\OneAgentSolver.py in <listcomp>(.0)
#      30
#      31     for episode in range(episode_n):
# ---> 32         sessions = [get_session(env, agent, session_len, agent_learning) for i in range(session_n)]
#      33
#      34         show(env, agent, episode, sessions)
#
# ~\Desktop\IMM-RL-Lab\finite-horizon_control_problems\Solvers\OneAgentSolver.py in get_session(env, agent, session_len, agent_learning)
#      16
#      17         if agent_learning=='by_fives':
# ---> 18             agent.fit(state, action, reward, done, next_state)
#      19
#      20         state = next_state
#
# ~\Desktop\IMM-RL-Lab\finite-horizon_control_problems\Agents\CVI.py in fit(self, state, action, reward, done, next_state)
#      82             v_values = self.v_model(states)
#      83             loss = torch.mean((v_values - targets.detach())**2)
# ---> 84             self.update_target_model(self.v_target_model, self.v_model, self.optimizer, loss)
#      85             return None
#      86
#
# ~\Desktop\IMM-RL-Lab\finite-horizon_control_problems\Agents\CVI.py in update_target_model(self, target_model, model, optimizer, loss)
#      88         optimizer.zero_grad()
#      89         loss.backward()
# ---> 90         optimizer.step()
#      91         for target_param, param in zip(target_model.parameters(), model.parameters()):
#      92             target_param.data.copy_((1 - self.tau) * target_param.data + self.tau * param.data)
#
# C:\users\anton\appdata\local\programs\python\python39\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# C:\users\anton\appdata\local\programs\python\python39\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# C:\users\anton\appdata\local\programs\python\python39\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     139                     state_steps.append(state['step'])
#     140
# --> 141             F.adam(params_with_grad,
#     142                    grads,
#     143                    exp_avgs,
#
# C:\users\anton\appdata\local\programs\python\python39\lib\site-packages\torch\optim\_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     108
#     109         step_size = lr / bias_correction1
# --> 110         param.addcdiv_(exp_avg, denom, value=-step_size)
#     111
#     112 def adamw(params: List[Tensor],
#
# KeyboardInterrupt:
