# %%
import os, sys
import matplotlib.pyplot as plt
sys.path.insert(0, os.path.abspath('..'))
from Utilities.OneAgentReader import OneAgentReader as Reader
# %load_ext autoreload
# %autoreload 2


reader = Reader(None)
reader.add_plots_for_all_params('CEM_Discrete', filter_str='SimpleControlProblem')

reader = Reader(None)
reader.add_plots_for_all_params('CEM_Discrete', filter_str='Pendulum')

reader = Reader(None)
reader.add_plots_for_all_params('CEM_Discrete', filter_str='DubinsCar')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
